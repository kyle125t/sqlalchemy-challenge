# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
base = automap_base()
# reflect the tables
base.prepare(engine, reflect = True)

# %%
# View all of the classes that automap found
base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
measurement = base.classes.measurement
station = base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Inspect 'measurement'
inspector = inspect(engine)
columns = inspector.get_columns("measurement")
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Inspect 'station'
columns = inspector.get_columns("station")
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Explore 'measurement' further
engine.execute("SELECT * FROM measurement LIMIT 20").fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0),
#  (6, 'USC00519397', '2010-01-07', 0.06, 70.0),
#  (7, 'USC00519397', '2010-01-08', 0.0, 64.0),
#  (8, 'USC00519397', '2010-01-09', 0.0, 68.0),
#  (9, 'USC00519397', '2010-01-10', 0.0, 73.0),
#  (10, 'USC00519397', '2010-01-11', 0.01, 64.0),
#  (11, 'USC00519397', '2010-01-12', 0.0, 61.0),
#  (12, 'USC00519397', '2010-01-14', 0.0, 66.0),
#  (13, 'USC00519397', '2010-01-15', 0.0, 65.0),
#  (14, 'USC00519397', '2010-01-16', 0.0, 68.0),
#  (15, 'USC00519397', '2010-01-17', 0.0, 64.0),
#  (16, 'USC00519397', '2010-01-18', 0.0, 72.0),
#  (17, 'USC00519397', '2010-01-19', 0.0, 66.0),
#  (18, 'USC00519397', '2010-01-20', 0.0, 66.0),
#  (19, 'USC00519397', '2010-01-21', 0.0, 69.0),
#  (20, 'USC00519397', '2010-01-22', 0.0, 67.0)]

# %%
engine.execute('SELECT * FROM station LIMIT 20').fetchall()
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (6, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (7, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (8, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (9, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
most_recent = session.query(measurement.date).order_by(measurement.date.desc()).first()
most_recent
# Out:
# ('2017-08-23')

# %%
# Calculate the date one year from the last date in data set.

year_ago = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print(year_ago)
# Out:
# 2016-08-23

# %%
# Perform a query to retrieve the data and precipitation scores
rain_year = session.query(measurement.date, measurement.prcp).\
    filter(measurement.date >= "2016-08-24", measurement.date <= "2017-08-23").\
    order_by(measurement.date).all()
rain_year
# Out:
# [('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.17),
#  ('2016-08-29', 0.04),
#  ('2016-08-29', None),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.35),
#  ('2016-08-29', 0.9),
#  ('2016-08-30', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
rain_year_df = pd.DataFrame(rain_year)
rain_year_df
# Out:
#             date  prcp
# 0     2016-08-24  0.08
# 1     2016-08-24  2.15
# 2     2016-08-24  2.28
# 3     2016-08-24   NaN
# 4     2016-08-24  1.22
# ...          ...   ...
# 2218  2017-08-22  0.50
# 2219  2017-08-23  0.00
# 2220  2017-08-23  0.00
# 2221  2017-08-23  0.08
# 2222  2017-08-23  0.45
#
# [2223 rows x 2 columns]

# %%
# Sort the dataframe by date
rain_year_df.set_index("date")
rain_year_df.head(10)
# Out:
#          date  prcp
# 0  2016-08-24  0.08
# 1  2016-08-24  2.15
# 2  2016-08-24  2.28
# 3  2016-08-24   NaN
# 4  2016-08-24  1.22
# 5  2016-08-24  2.15
# 6  2016-08-24  1.45
# 7  2016-08-25  0.08
# 8  2016-08-25  0.08
# 9  2016-08-25  0.00

# %%
# Use Pandas Plotting with Matplotlib to plot the data
plt.plot(rain_year_df["date"], rain_year_df["prcp"])
plt.xlabel("Date", fontsize = 10)
plt.ylabel("Rainfall (Inches)", fontsize = 10)
plt.legend(["Precipitation"], loc = "upper right", fontsize = 10)
plt.xticks([])
plt.savefig("../Images/Precipitation.png")
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
rain_year_df.describe()
# Out:
#               prcp
# count  2015.000000
# mean      0.176462
# std       0.460288
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
stations = session.query(station.id).distinct().count()
stations
# Out:
# 9

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
station_activity = session.query(measurement.station, func.count(measurement.station)).\
    group_by(measurement.station).\
    order_by(func.count(measurement.station).desc()).all()
station_activity
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
most_active = "USC00519281"
MA_query = session.query(func.min(measurement.tobs), func.max(measurement.tobs), func.avg(measurement.tobs)).\
    filter(measurement.station == most_active).all()
MA_query
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
print(f"Lowest temperature: {MA_query[0][0]} degrees Fahrenheit")
print(f"Highest temperature: {MA_query[0][1]} degrees Fahrenheit")
print(f"Average temperature: {MA_query[0][2]} degrees Fahrenheit")
# Out:
# Lowest temperature: 54.0 degrees Fahrenheit
# Highest temperature: 85.0 degrees Fahrenheit
# Average temperature: 71.66378066378067 degrees Fahrenheit

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station
MA_12 = session.query(measurement.date, measurement.tobs).\
    filter(measurement.date >= year_ago).\
    filter(measurement.station == most_active).\
    order_by(measurement.date.desc()).all()
MA_12_df = pd.DataFrame(MA_12)
MA_12_df.set_index("date", inplace = True)

# %%
# And plot the results as a histogram
fig, ax = plt.subplots()
MA_12_df.plot.hist(bins = 12, ax = ax)

plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.title(f"Last 12 Months of Temperature Data for Station {most_active}")
plt.grid(True)
plt.savefig("../Images/Histogram.png")
plt.show()

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
